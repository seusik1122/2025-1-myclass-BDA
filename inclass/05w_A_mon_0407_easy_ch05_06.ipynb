# %% [markdown]
# <a href="https://colab.research.google.com/github/seusik1122/2025-1-myclass-BDA/blob/main/inclass/05w_A_mon_0407_easy_ch05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #05주

# %% [markdown]
# ##p116 05-3 파생변수 생성

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({'var1': [4,3,8], 'var2':[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1 = df.copy()
df1
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df1['var_sum'] = df1.var1 +df1.var2
df1
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1.var_sum2 = df1.var1 +df1.var2
df1
# Out:
# <ipython-input-8-b303e094338d>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.var_sum2 = df1.var1 +df1.var2
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df1['var_maean'] = (df1.var1 +df1.var2) / 2
df1
# Out:
#    var1  var2  var_sum  var_maean
# 0     4     2        6        3.0
# 1     3     6        9        4.5
# 2     8     1        9        4.5

# %%
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2 = df.copy()
df2
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df2.sum()
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=0)
# Out:
# var1    15
# var2     9
# dtype: int64

# %%
df2.sum(axis=1)
# Out:
# 0    6
# 1    9
# 2    9
# dtype: int64

# %%
df2['my_sum'] = df2.sum(axis=1)
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      12
# 1     3     6      18
# 2     8     1      18

# %%
df2['my_sum'] = df2.sum(axis='columns')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2      18
# 1     3     6      27
# 2     8     1      27

# %%
df2['my_sum'] = df2.sum(axis='index')
df2
# Out:
#    var1  var2  my_sum
# 0     4     2     NaN
# 1     3     6     NaN
# 2     8     1     NaN

# %%
df2[['var1','var2']]
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df['var1']
# Out:
# 0    4
# 1    3
# 2    8
# Name: var1, dtype: int64

# %%
df['var2']
# Out:
# 0    2
# 1    6
# 2    1
# Name: var2, dtype: int64

# %%
df2['my_mean'] = df2[['var1', 'var2']].mean(axis=1)
df2
# Out:
#    var1  var2  my_sum  my_mean
# 0     4     2     NaN      3.0
# 1     3     6     NaN      4.5
# 2     8     1     NaN      4.5

# %% [markdown]
# ##mpg 데이터(시험예상)

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# Cloning into 'data'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 24 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 2.14 MiB | 5.31 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
mpg = pd.read_csv('data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
 mpg.sample()
# Out:
#     manufacturer               model  displ  year  cyl     trans drv  cty  \
# 128         jeep  grand cherokee 4wd    5.7  2008    8  auto(l5)   4   13
#
#      hwy fl category
# 128   18  r      suv

# %%
mpg['total'] = (mpg.cty + mpg.hwy) / 2
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total
# 0   23.5
# 1   25.0
# 2   25.5
# 3   25.5
# 4   21.0

# %%
mpg['mpg_mean'] = mpg[['cty', 'hwy']].mean(axis='columns')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
#
#    total  mpg_mean
# 0   23.5      23.5
# 1   25.0      25.0
# 2   25.5      25.5
# 3   25.5      25.5
# 4   21.0      21.0

# %%
sum(mpg['total']) / len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# np.float64(20.14957264957265)

# %%
mpg.shape
# Out:
# (234, 13)

# %%
len(mpg)
# Out:
# 234

# %%
sum(mpg['total']) / mpg.shape[0]
# Out:
# 20.14957264957265

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg.total.describe()['mean']
# Out:
# np.float64(20.14957264957265)

# %%
mpg.total.describe()[1]
# Out:
# <ipython-input-39-b4aef9eccf3a>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mpg.total.describe()[1]
# np.float64(20.14957264957265)

# %%
mpg.total.plot.hist();

# %%
import koreanize_matplotlib

# %%
# %config inlineBackend.figure_format = 'retina'

# %%
mpg.total.plot(kind="hist", title="히스토그램");

# %%
import seaborn as sns

sns.histplot(mpg, x="total")
# Out:
# <Axes: xlabel='total', ylabel='Count'>

# %% [markdown]
# ##np.where()

# %%
np.where(mpg.total >=20, 'pass', 'fail')
# Out:
# array(['pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail',
#        'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'pass',
#        'fail', 'pass', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail',
#        'fail', 'pass', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail', 'fail',
#        'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'fail', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'fail', 'fail',
#        'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'fail', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'fail', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass', 'pass',
#        'pass', 'pass'], dtype='<U4')

# %%
mpg['test'] = np.where(mpg.total >=20, 'pass', 'fail')
mpg.sample(5)
# Out:
#     manufacturer               model  displ  year  cyl     trans drv  cty  \
# 135      lincoln       navigator 2wd    5.4  1999    8  auto(l4)   r   11
# 128         jeep  grand cherokee 4wd    5.7  2008    8  auto(l5)   4   13
# 138      mercury     mountaineer 4wd    4.0  2008    6  auto(l5)   4   13
# 47         dodge         caravan 2wd    4.0  2008    6  auto(l6)   f   16
# 217   volkswagen               jetta    2.5  2008    5  auto(s6)   f   21
#
#      hwy fl category  total  mpg_mean  test
# 135   16  p      suv   13.5      13.5  fail
# 128   18  r      suv   15.5      15.5  fail
# 138   19  r      suv   16.0      16.0  fail
# 47    23  r  minivan   19.5      19.5  fail
# 217   29  r  compact   25.0      25.0  pass

# %%
mpg['test'].value_counts()
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
mpg['test'].unique()
# Out:
# array(['pass', 'fail'], dtype=object)

# %%
count_test = mpg['test'].value_counts()
count_test
# Out:
# test
# pass    128
# fail    106
# Name: count, dtype: int64

# %%
count_test.plot.bar()
# Out:
# <Axes: xlabel='test'>

# %%
count_test.plot.bar(rot = 0)
# Out:
# <Axes: xlabel='test'>

# %%
sns.countplot(mpg, x="test")
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(mpg, x="test", hue="test")
# Out:
# <Axes: xlabel='test', ylabel='count'>

# %%
sns.countplot(mpg, x="test", hue="test", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg, x="test", hue="cyl", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
sns.countplot(mpg, x="test", hue="category", stat="percent")
# Out:
# <Axes: xlabel='test', ylabel='percent'>

# %%
mpg['grade'] = np.where(mpg['total'] >= 30, 'A', np.where(mpg['total'] >= 20, 'B', 'C'))
mpg.sample(5)
# Out:
#     manufacturer                model  displ  year  cyl       trans drv  cty  \
# 166       subaru          impreza awd    2.2  1999    4  manual(m5)   4   19
# 124         jeep   grand cherokee 4wd    4.0  1999    6    auto(l4)   4   15
# 33     chevrolet               malibu    2.4  2008    4    auto(l4)   f   22
# 68         dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4   12
# 55         dodge    dakota pickup 4wd    5.2  1999    8  manual(m5)   4   11
#
#      hwy fl    category  total  mpg_mean  test grade
# 166   26  r  subcompact   22.5      22.5  pass     B
# 124   20  r         suv   17.5      17.5  fail     C
# 33    30  r     midsize   26.0      26.0  pass     B
# 68    16  r      pickup   14.0      14.0  fail     C
# 55    17  r      pickup   14.0      14.0  fail     C

# %%
count_grade = mpg['grade'].value_counts()
count_grade
# Out:
# grade
# B    118
# C    106
# A     10
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot = 0)
# Out:
# <Axes: xlabel='grade'>

# %%
count_grade = mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# grade
# A     10
# B    118
# C    106
# Name: count, dtype: int64

# %%
count_grade.plot.bar(rot = 0);

# %%
sns.countplot(mpg, x='grade', hue='grade')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
sns.countplot(mpg, x='grade', hue='grade', stat='percent')
# Out:
# <Axes: xlabel='grade', ylabel='percent'>

# %%
mpg['grade'].value_counts().sort_index().index
# Out:
# Index(['A', 'B', 'C'], dtype='object', name='grade')

# %%
sns.countplot(mpg, x="grade", hue="grade", order=mpg.grade.value_counts().sort_index().index);

# %%
sns.countplot(mpg, x="grade", hue="grade", order=["A", "B", "C"]);

# %%
np.sort(mpg.grade.unique())
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %%
sns.countplot(mpg, x="grade", hue="grade", order=np.sort(mpg.grade.unique()));

# %%
s = mpg['grade']
s= s.value_counts()
s = s.sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
s= mpg.grade.value_counts().sort_index()
type(s)
# Out:
# pandas.core.series.Series

# %%
mpg['grade2'] =  np.where(mpg['total'] >= 30, 'A',
                np.where(mpg['total'] >= 25, 'B',
                np.where(mpg['total'] >= 20, 'C', 'D')))
mpg.sample(5)
# Out:
#     manufacturer            model  displ  year  cyl       trans drv  cty  hwy  \
# 184       toyota            camry    3.0  1999    6  manual(m5)   f   18   26
# 138      mercury  mountaineer 4wd    4.0  2008    6    auto(l5)   4   13   19
# 135      lincoln    navigator 2wd    5.4  1999    8    auto(l4)   r   11   16
# 156      pontiac       grand prix    3.8  1999    6    auto(l4)   f   17   27
# 118      hyundai          tiburon    2.0  2008    4    auto(l4)   f   20   27
#
#     fl    category  total  mpg_mean  test grade grade2
# 184  r     midsize   22.0      22.0  pass     B      C
# 138  r         suv   16.0      16.0  fail     C      D
# 135  p         suv   13.5      13.5  fail     C      D
# 156  r     midsize   22.0      22.0  pass     B      C
# 118  r  subcompact   23.5      23.5  pass     B      C

# %%
mpg['size'] = np.where((mpg.category == 'compact') | (mpg.category == 'subcompact') | (mpg.category == '2seater'), 'small', 'large')
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg['size'] = np.where(mpg.category.isin(['compact', 'subcompact', '2seater']), 'small', 'large') #시험예상
mpg['size'].value_counts()
# Out:
# size
# large    147
# small     87
# Name: count, dtype: int64

# %%
mpg.sample(3)
# Out:
#      company   model  displ  year  cyl       trans drv  cty  hwy fl category  \
# 141   nissan  altima    2.4  1999    4  manual(m5)   f   21   29  r  compact
# 112  hyundai  sonata    2.5  1999    6    auto(l4)   f   18   26  r  midsize
# 180   toyota   camry    2.2  1999    4    auto(l4)   f   21   27  r  midsize
#
#      total  test
# 141   25.0  pass
# 112   22.0  pass
# 180   24.0  pass

# %%
mpg.size
# Out:
# 3042

# %%
mpg.shape
# Out:
# (234, 13)

# %%
mpg.shape[0] * mpg.shape[1]
# Out:
# 3042

# %% [markdown]
# ##정리하기

# %%
import pandas as pd
import numpy as np

mpg = pd.read_csv('data/mpg.csv')

mpg.shape
mpg.head()
mpg.tail()
mpg.info()
mpg.describe()

mpg = mpg.rename(columns = {'manufacturer' : 'company'})

mpg['total'] = (mpg['cty'] + mpg['hwy'])/2
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')

count_test = mpg['test'].value_counts()
count_test.plot.bar(rot= 0)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB
# <Axes: xlabel='test'>

# %% [markdown]
# #단원06

# %%
exam = pd.read_csv('data/exam.csv')
exam.sample(5)
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 17  18       5    80       78       90
# 14  15       4    75       56       78
# 4    5       2    25       80       65
# 0    1       1    50       98       50

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes

# %%
exam.sample(frac=.2)
# Out:
#     id  nclass  math  english  science
# 15  16       4    58       98       65
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65

# %%
exam.query('nclass==1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass!=1')
# Out:
#     id  nclass  math  english  science
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam['nclass'] == 2
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5      True
# 6      True
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: nclass, dtype: bool

# %%
exam[exam['nclass'] == 2]
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
exam.query('math > 50')
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 10  11       3    65       65       65
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('english >= 80')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 19  20       5    78       83       58

# %%
exam.query('nclass == 1 & math >= 50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam.nclass == 1) & (exam.math >= 50)]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('english < 90 | science < 50')
# Out:
#     id  nclass  math  english  science
# 2    3       1    45       86       78
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass ==1 | nclass == 3 | nclass == 5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
a = [1,3, 5]
1 in a
# Out:
# True

# %%
4 in a
# Out:
# False

# %%
exam.query('nclass in [1,3,5]')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.query('nclass.isin([1,3,5])')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam[exam.nclass.isin([1, 3, 5])]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1 = exam.query('nclass == 1')
nclass1
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
nclass2 = exam.query('nclass==2')
nclass2
# Out:
#    id  nclass  math  english  science
# 4   5       2    25       80       65
# 5   6       2    50       89       98
# 6   7       2    80       90       45
# 7   8       2    90       78       25

# %%
nclass1["math"].mean()
# Out:
# np.float64(46.25)

# %%
nclass2.english.mean()
# Out:
# np.float64(84.25)

# %%
df = pd.DataFrame({'sex' : ['M', 'F', 'M', 'F'], 'country' : ['Korea', 'Japan', 'China', 'USA']})
df
# Out:
#   sex country
# 0   M   Korea
# 1   F   Japan
# 2   M   China
# 3   F     USA

# %%
df.query('sex == "M" & country == "Korea"')
# Out:
#   sex country
# 0   M   Korea

# %%
var = 3
exam.query('nclass == @var')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
df = pd.DataFrame({'num_legs': [2, 4], 'num_wings': [2, 0]},
                  index=['falcon', 'dog'])
df
# Out:
#         num_legs  num_wings
# falcon         2          2
# dog            4          0

# %%
df.isin([0,4])
# Out:
#         num_legs  num_wings
# falcon     False      False
# dog         True       True

# %%
~df.isin([0,4])
# Out:
#         num_legs  num_wings
# falcon      True       True
# dog        False      False

# %%
exam.columns
# Out:
# Index(['id', 'nclass', 'math', 'english', 'science'], dtype='object')

# %%
exam.columns[2]
# Out:
# 'math'

# %%
exam["math"]
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.math
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam.columns[1:4]
# Out:
# Index(['nclass', 'math', 'english'], dtype='object')

# %%
exam[exam.columns[1:4]]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam[['nclass', 'math', 'english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam[['nclass', 'math', 'english']].head()
# Out:
#    nclass  math  english
# 0       1    50       98
# 1       1    60       97
# 2       1    45       86
# 3       1    30       98
# 4       2    25       80

# %%
exam.drop(columns=["math", "english"])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(columns=["math"])
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index=2)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop([2,4,6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(index = [2,4,6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2,4,6])
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=[2, 4, 6], axis=0)
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 5    6       2    50       89       98
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.drop(labels=['math', 'english'], axis=1)
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
exam.query('nclass == 1')['math']
# Out:
# 0    50
# 1    60
# 2    45
# 3    30
# Name: math, dtype: int64

# %%
exam.query('nclass == 1')['math'].to_frame()
# Out:
#    math
# 0    50
# 1    60
# 2    45
# 3    30

# %%
exam.query('nclass == 1')[['math', 'science']]
# Out:
#    math  science
# 0    50       50
# 1    60       60
# 2    45       78
# 3    30       58

# %%
exam.query('math >= 50')[['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
exam[exam.math >= 50][['id', 'math']].head(5)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %%
exam[exam.math >= 50]\
    [['id', 'math']]\
    .head(5)
# Out:
#    id  math
# 0   1    50
# 1   2    60
# 5   6    50
# 6   7    80
# 7   8    90

# %% [markdown]
# ##정렬

# %%
exam.sort_values('math', ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values('math', ascending=False).head(5)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58

# %%
exam.sort_values(['nclass', 'math'], ascending=[True, False]).head(10)
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45

# %%
exam.sort_values(['nclass', 'math'], ascending=[True, True]).head(10)
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32

# %%
exam.sort_index()
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.sort_index(ascending=False).head(3)
# Out:
#     id  nclass  math  english  science
# 19  20       5    78       83       58
# 18  19       5    89       68       87
# 17  18       5    80       78       90

# %%
exam.sort_index(axis=1, ascending=False).head(3)
# Out:
#    science  nclass  math  id  english
# 0       50       1    50   1       98
# 1       60       1    60   2       97
# 2       78       1    45   3       86

# %%
exam.sort_index(axis=1).head(3)
# Out:
#    english  id  math  nclass  science
# 0       98   1    50       1       50
# 1       97   2    60       1       60
# 2       86   3    45       1       78

# %% [markdown]
# #종료
